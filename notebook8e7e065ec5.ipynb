# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from matplotlib import pyplot as plt 
import cv2 as cv
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T110320Z.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T110923Z.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T142031Z.xml
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T151042Z.xml
# /kaggle/input/licenseplate/captrue/45.jpg
# /kaggle/input/licenseplate/captrue/56.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221107T180522Z.xml
# /kaggle/input/licenseplate/captrue/89.jpg
# /kaggle/input/licenseplate/captrue/20.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221109T090646Z.xml
# /kaggle/input/licenseplate/captrue/58.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T113913Z.xml
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T142115Z.xml
# /kaggle/input/licenseplate/captrue/6.jpg
# /kaggle/input/licenseplate/captrue/E19397879_1_20221108T113235Z.xml
# /kaggle/input/licenseplate/captrue/76.jpg
# /kaggle/input/licenseplate/captrue/71.jpg
# ...

# %%
fig,ax = plt.subplots(1,4,figsize=(10,5))
image = cv.imread("../input/licenseplate/captrue/E19397879_1_20221108T090042Z.jpg")
ax[0].imshow(image)
image = cv.imread("../input/licenseplate/captrue/E19397879_1_20221108T113927Z.jpg")
ax[1].imshow(image)
image = cv.imread("../input/licenseplate/captrue/E19397879_1_20221108T125114Z.jpg")
ax[2].imshow(image)
image = cv.imread("../input/licenseplate/captrue/E19397879_1_20221108T092452Z.jpg")
ax[3].imshow(image)
fig.show()

# %%
# %cd ../
# !mkdir tmp
# %cd tmp
# Out:
# /kaggle
# /kaggle/tmp

# %%
# Download YOLOv7
# !git clone https://github.com/WongKinYiu/yolov7.git # clone repo
# %cd yolov7
# Install dependencies
# %pip install -qr requirements.txt  # install dependencies
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt"
# %ls
# %cd ../
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov7'...
# fatal: unable to access 'https://github.com/WongKinYiu/yolov7.git/': Could not resolve host: github.com
# [Errno 2] No such file or directory: 'yolov7'
# /kaggle/tmp
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# --2022-12-23 14:39:29--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt
# Resolving github.com (github.com)... failed: Temporary failure in name resolution.
# wget: unable to resolve host address ‘github.com’
# /kaggle
# Setup complete. Using torch 1.11.0+cpu (CPU)
